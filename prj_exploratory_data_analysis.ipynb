# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('good_samples_cleaned.csv')

df.head(5)
# Out:
#        LogName        Date         Time ComputerName  \
# 0  Application  09/22/2023  12:10:15 AM    CLIENT-PC
# 1       System  09/22/2023  12:10:01 AM    CLIENT-PC
# 2  Application  09/22/2023  12:09:45 AM    CLIENT-PC
# 3       System  09/22/2023  12:09:23 AM    CLIENT-PC
# 4  Application  09/22/2023  12:09:20 AM    CLIENT-PC
#
#                          SourceName TaskCategory  EventType Keywords OpCode  \
# 0    Microsoft-Windows-Security-SPP          NaN          4  Classic    NaN
# 1  Microsoft-Windows-Kernel-General          NaN          4      NaN   Info
# 2                    SecurityCenter          NaN          4  Classic   Info
# 3  Microsoft-Windows-Kernel-General          NaN          4      NaN   Info
# 4    Microsoft-Windows-Security-SPP          NaN          2  Classic    NaN
#
#    EventCode  Type  RecordNumber  \
# 0      16384     4          3267
# 1         16     4          2279
# 2         15     4          3266
# 3         16     4          2278
# 4       8198     2          3265
#
#                                              Message
# 0  Successfully scheduled Software Protection ser...
# 1  The access history in hive \??\C:\Users\Commun...
# 2  Updated Windows Defender status successfully t...
# 3  The access history in hive \??\C:\Users\Commun...
# 4  License Activation (slui.exe) failed with the ...

# %%
df.describe(include='all')
# Out:
#             LogName        Date         Time ComputerName  \
# count           351         351          351          351
# unique            4           2          154            1
# top     Application  09/21/2023  12:04:39 AM    CLIENT-PC
# freq            164         180           30          351
# mean            NaN         NaN          NaN          NaN
# std             NaN         NaN          NaN          NaN
# min             NaN         NaN          NaN          NaN
# 25%             NaN         NaN          NaN          NaN
# 50%             NaN         NaN          NaN          NaN
# 75%             NaN         NaN          NaN          NaN
# max             NaN         NaN          NaN          NaN
#
#                             SourceName      TaskCategory   EventType Keywords  \
# count                              351               103  351.000000      223
# unique                              33                27         NaN        6
# top     Microsoft-Windows-Security-SPP  Process Creation         NaN  Classic
# freq                               108                24         NaN      182
# mean                               NaN               NaN    3.527066      NaN
# std                                NaN               NaN    1.213605      NaN
# min                                NaN               NaN    0.000000      NaN
# 25%                                NaN               NaN    4.000000      NaN
# 50%                                NaN               NaN    4.000000      NaN
# 75%                                NaN               NaN    4.000000      NaN
# max                                NaN               NaN    4.000000      NaN
#
#        OpCode     EventCode        Type   RecordNumber  \
# count     227    351.000000  351.000000     351.000000
# unique      9           NaN         NaN            NaN
# top      Info           NaN         NaN            NaN
# freq      192           NaN         NaN            NaN
# mean      NaN   5216.168091    3.527066   26983.341880
# std       NaN  10009.865987    1.213605   82661.642981
# min       NaN      0.000000    0.000000      25.000000
# 25%       NaN     16.000000    4.000000    2208.500000
# 50%       NaN   1004.000000    4.000000    3120.000000
# 75%       NaN   6005.500000    4.000000    3207.500000
# max       NaN  51057.000000    4.000000  307345.000000
#
#                                                   Message
# count                                                 351
# unique                                                180
# top     The Software Protection service has successful...
# freq                                                   36
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

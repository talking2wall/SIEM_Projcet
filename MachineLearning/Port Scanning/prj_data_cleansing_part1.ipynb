# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from collections import Counter

# show several prints in one cell. This will allow us to condence every trick in one cell.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# %matplotlib inline

# %% [markdown]
# Let's load the dataset, and analyze it:

# %%
df = pd.read_csv('good_samples.csv')

df.head(2)
# Out:
#   Account_Domain Account_Name Additional_Data Advanced_Options  \
# 0            NaN          NaN             NaN              NaN
# 1            NaN          NaN             NaN              NaN
#
#    Analysis_symbol  Cab_Guid  Cab_Id ComputerName Configuration_Access_Policy  \
# 0              NaN       NaN     NaN    CLIENT-PC                         NaN
# 1              NaN       NaN     NaN    CLIENT-PC                         NaN
#
#   Creator_Process_ID Creator_Process_Name Disable_Integrity_Checks  EventCode  \
# 0                NaN                  NaN                      NaN      16384
# 1                NaN                  NaN                      NaN         16
#
#    EventType Event_Name Exception_code Fault_offset Faulting_application_path  \
# 0          4        NaN            NaN          NaN                       NaN
# 1          4        NaN            NaN          NaN                       NaN
#
#   Faulting_application_start_time Faulting_module_name Faulting_module_path  \
# 0                             NaN                  NaN                  NaN
# 1                             NaN                  NaN                  NaN
#
#   Faulting_package_full_name Faulting_package_relative_application_ID  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
#
#   Faulting_process_id Flight_Signing Hashed_bucket HyperVisor_Debugging  \
# 0                 NaN            NaN           NaN                  NaN
# 1                 NaN            NaN           NaN                  NaN
#
#   HyperVisor_Launch_Type HyperVisor_Load_Options Idle_state_type  \
# 0                    NaN                     NaN             NaN
# 1                    NaN                     NaN             NaN
#
#    Internal_Timing_Sequence Kernel_Debugging Keywords Leap_seconds_enabled  \
# 0                       NaN              NaN  Classic                  NaN
# 1                       NaN              NaN      NaN                  NaN
#
#   Load_Options      LogName Logon_ID Mandatory_Label  \
# 0          NaN  Application      NaN             NaN
# 1          NaN       System      NaN             NaN
#
#    Maximum_performance_percentage  \
# 0                             NaN
# 1                             NaN
#
#                                              Message  MinimumPasswordLength  \
# 0  Successfully scheduled Software Protection ser...                    NaN
# 1  The access history in hive \??\C:\Users\Commun...                    NaN
#
#    MinimumPasswordLengthAudit  Minimum_performance_percentage  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
#
#    Minimum_throttle_percentage New_Process_ID New_Process_Name  \
# 0                          NaN            NaN              NaN
# 1                          NaN            NaN              NaN
#
#    New_leap_second_count  Nominal_Frequency__MHz_  Old_leap_second_count  \
# 0                    NaN                      NaN                    NaN
# 1                    NaN                      NaN                    NaN
#
#   OpCode   P1  P10   P2   P3   P4   P5   P6   P7  P8   P9  \
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  NaN
# 1   Info  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  NaN
#
#    Performance_state_type  Process_Command_Line Process_ID  Process_Name  \
# 0                     NaN                   NaN        NaN           NaN
# 1                     NaN                   NaN        NaN           NaN
#
#    Processing_Stats Reason Reason_Code  Rechecking_for_solution  RecordNumber  \
# 0               NaN    NaN         NaN                      NaN          3267
# 1               NaN    NaN         NaN                      NaN          2279
#
#    RelaxMinimumPasswordLengthLimits Report_Id  Report_Status Response  \
# 0                               NaN       NaN            NaN      NaN
# 1                               NaN       NaN            NaN      NaN
#
#   Saved_Cache Security_ID Service_Account Service_File_Name Service_Name  \
# 0         NaN         NaN             NaN               NaN          NaN
# 1         NaN         NaN             NaN               NaN          NaN
#
#   Service_Start_Type Service_Type Shutdown_Reason Shutdown_Type  \
# 0                NaN          NaN             NaN           NaN
# 1                NaN          NaN             NaN           NaN
#
#                                               Sid  SidType  \
# 0                                             NaN      NaN
# 1  S-1-5-21-1948427861-2696874323-1688284928-1000    0.000
#
#                          SourceName System_Event_Logging Target_Process_ID  \
# 0    Microsoft-Windows-Security-SPP                  NaN               NaN
# 1  Microsoft-Windows-Kernel-General                  NaN               NaN
#
#   Target_Process_Name TaskCategory Test_Signing Token_Elevation_Type  \
# 0                 NaN          NaN          NaN                  NaN
# 1                 NaN          NaN          NaN                  NaN
#
#           Type            User VSM_Launch_Type  \
# 0  Information             NaN             NaN
# 1  Information  NOT_TRANSLATED             NaN
#
#                                                 _raw  \
# 0  09/22/2023 12:10:15 AM\nLogName=Application\nE...
# 1  09/22/2023 12:10:01 AM\nLogName=System\nEventC...
#
#                            _time  alert  alert_time  app  category  date_hour  \
# 0  2023-09-22T00:10:15.000+03:00    NaN         NaN  NaN       NaN        NaN
# 1  2023-09-22T00:10:01.000+03:00    NaN         NaN  NaN       NaN        NaN
#
#    date_mday  date_minute  date_month  date_second  date_wday  date_year  \
# 0        NaN          NaN         NaN          NaN        NaN        NaN
# 1        NaN          NaN         NaN          NaN        NaN        NaN
#
#    date_zone  display_fields  earliest  eventSearch  eventtype  field_list{}  \
# 0        NaN             NaN       NaN          NaN        NaN           NaN
# 1        NaN             NaN       NaN          NaN        NaN           NaN
#
#    fields{}.Account_Domain  fields{}.Account_Name  fields{}.Additional_Data  \
# 0                      NaN                    NaN                       NaN
# 1                      NaN                    NaN                       NaN
#
#    fields{}.Advanced_Options  fields{}.Analysis_symbol  fields{}.Cab_Guid  \
# 0                        NaN                       NaN                NaN
# 1                        NaN                       NaN                NaN
#
#    fields{}.Cab_Id  fields{}.ComputerName  \
# 0              NaN                    NaN
# 1              NaN                    NaN
#
#    fields{}.Configuration_Access_Policy  fields{}.Creator_Process_ID  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
#
#    fields{}.Creator_Process_Name  fields{}.Disable_Integrity_Checks  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
#
#    fields{}.EventCode  fields{}.EventType  fields{}.Event_Name  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
#
#    fields{}.Exception_code  fields{}.Fault_offset  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
#
#    fields{}.Faulting_application_path  \
# 0                                 NaN
# 1                                 NaN
#
#    fields{}.Faulting_application_start_time  fields{}.Faulting_module_name  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
#
#    fields{}.Faulting_module_path  fields{}.Faulting_package_full_name  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
#
#    fields{}.Faulting_package_relative_application_ID  \
# 0                                                NaN
# 1                                                NaN
#
#    fields{}.Faulting_process_id  fields{}.Flight_Signing  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
#
#    fields{}.Hashed_bucket  fields{}.HyperVisor_Debugging  \
# 0                     NaN                            NaN
# 1                     NaN                            NaN
#
#    fields{}.HyperVisor_Launch_Type  fields{}.HyperVisor_Load_Options  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
#
#    fields{}.Idle_state_type  fields{}.Internal_Timing_Sequence  \
# 0                       NaN                                NaN
# 1                       NaN                                NaN
#
#    fields{}.Kernel_Debugging  fields{}.Keywords  \
# 0                        NaN                NaN
# 1                        NaN                NaN
#
#    fields{}.Leap_seconds_enabled  fields{}.Load_Options  fields{}.LogName  \
# 0                            NaN                    NaN               NaN
# 1                            NaN                    NaN               NaN
#
#    fields{}.Logon_ID  fields{}.Mandatory_Label  \
# 0                NaN                       NaN
# 1                NaN                       NaN
#
#    fields{}.Maximum_performance_percentage  fields{}.Message  \
# 0                                      NaN               NaN
# 1                                      NaN               NaN
#
#    fields{}.MinimumPasswordLength  fields{}.MinimumPasswordLengthAudit  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
#
#    fields{}.Minimum_performance_percentage  \
# 0                                      NaN
# 1                                      NaN
#
#    fields{}.Minimum_throttle_percentage  fields{}.New_Process_ID  \
# 0                                   NaN                      NaN
# 1                                   NaN                      NaN
#
#    fields{}.New_Process_Name  fields{}.New_leap_second_count  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
#
#    fields{}.Nominal_Frequency__MHz_  fields{}.Old_leap_second_count  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
#
#    fields{}.OpCode  fields{}.P1  fields{}.P10  fields{}.P2  fields{}.P3  \
# 0              NaN          NaN           NaN          NaN          NaN
# 1              NaN          NaN           NaN          NaN          NaN
#
#    fields{}.P4  fields{}.P5  fields{}.P6  fields{}.P7  fields{}.P8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#    fields{}.P9  fields{}.Performance_state_type  \
# 0          NaN                              NaN
# 1          NaN                              NaN
#
#    fields{}.Process_Command_Line  fields{}.Process_ID  fields{}.Process_Name  \
# 0                            NaN                  NaN                    NaN
# 1                            NaN                  NaN                    NaN
#
#    fields{}.Reason  fields{}.Reason_Code  fields{}.Rechecking_for_solution  \
# 0              NaN                   NaN                               NaN
# 1              NaN                   NaN                               NaN
#
#    fields{}.RecordNumber  fields{}.RelaxMinimumPasswordLengthLimits  \
# 0                    NaN                                        NaN
# 1                    NaN                                        NaN
#
#    fields{}.Report_Id  fields{}.Report_Status  fields{}.Response  \
# 0                 NaN                     NaN                NaN
# 1                 NaN                     NaN                NaN
#
#    fields{}.Saved_Cache  fields{}.Security_ID  fields{}.Service_Account  \
# 0                   NaN                   NaN                       NaN
# 1                   NaN                   NaN                       NaN
#
#    fields{}.Service_File_Name  fields{}.Service_Name  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
#
#    fields{}.Service_Start_Type  fields{}.Service_Type  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
#
#    fields{}.Shutdown_Reason  fields{}.Shutdown_Type  fields{}.Sid  \
# 0                       NaN                     NaN           NaN
# 1                       NaN                     NaN           NaN
#
#    fields{}.SidType  fields{}.SourceName  fields{}.System_Event_Logging  \
# 0               NaN                  NaN                            NaN
# 1               NaN                  NaN                            NaN
#
#    fields{}.Target_Process_ID  fields{}.Target_Process_Name  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
#
#    fields{}.TaskCategory  fields{}.Test_Signing  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
#
#    fields{}.Token_Elevation_Type  fields{}.Type  fields{}.User  \
# 0                            NaN            NaN            NaN
# 1                            NaN            NaN            NaN
#
#    fields{}.VSM_Launch_Type  fields{}._confstr  fields{}._eventtype_color  \
# 0                       NaN                NaN                        NaN
# 1                       NaN                NaN                        NaN
#
#    fields{}._indextime  fields{}._pre_msg  fields{}._raw  fields{}._serial  \
# 0                  NaN                NaN            NaN               NaN
# 1                  NaN                NaN            NaN               NaN
#
#    fields{}._si  fields{}._sourcetype  fields{}._time  fields{}.eventtype  \
# 0           NaN                   NaN             NaN                 NaN
# 1           NaN                   NaN             NaN                 NaN
#
#    fields{}.host  fields{}.index  fields{}.linecount  fields{}.punct  \
# 0            NaN             NaN                 NaN             NaN
# 1            NaN             NaN                 NaN             NaN
#
#    fields{}.source  fields{}.sourcetype  fields{}.splunk_server       host  \
# 0              NaN                  NaN                     NaN  CLIENT-PC
# 1              NaN                  NaN                     NaN  CLIENT-PC
#
#    impact  incident_id index  job_id  label  latest  linecount  name  owner  \
# 0     NaN          NaN  main     NaN    NaN     NaN         12   NaN    NaN
# 1     NaN          NaN  main     NaN    NaN     NaN         15   NaN    NaN
#
#    priority                                              punct  result_id  \
# 0       NaN            //_::_====-=---======______-__--::._:_.        NaN
# 1       NaN  //_::_====-==-------==---======_____\??\:\\\\\...        NaN
#
#                     source               sourcetype splunk_server  \
# 0  WinEventLog:Application  WinEventLog:Application          SIEM
# 1       WinEventLog:System       WinEventLog:System          SIEM
#
#    splunk_server_group  subcategory  tags  timeendpos  timestartpos  title  \
# 0                  NaN          NaN   NaN         NaN           NaN    NaN
# 1                  NaN          NaN   NaN         NaN           NaN    NaN
#
#    ttl  urgency
# 0  NaN      NaN
# 1  NaN      NaN

# %% [markdown]
# Let's check what types of windows logs we are dealing with:

# %%
# Collect the lof type from every log in the dataset
list_of_types = []
for i, j in df.iterrows():
    list_of_types.append(re.search('LogName=(.*)\n', j['_raw']).group(1))

# Show how the log types are divided
colors = sns.color_palette('pastel')[0:5]
set_of_types = set(list_of_types)
values = [list_of_types.count(x) for x in set_of_types]
plt.pie(values, labels = set_of_types, colors = colors, autopct='%.0f%%')
plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x1b38f7ae6d0>,
#   <matplotlib.patches.Wedge at 0x1b38f7c0050>,
#   <matplotlib.patches.Wedge at 0x1b38f7c1890>,
#   <matplotlib.patches.Wedge at 0x1b38f7c10d0>],
#  [Text(0.11302285131835614, 1.0941781550916967, 'Application'),
#   Text(-1.0988986772359721, -0.04921074241495367, 'Security'),
#   Text(0.13259028929709082, -1.0919797686697836, 'System'),
#   Text(1.0996034791891174, -0.029532838590093417, 'Setup')],
#  [Text(0.061648827991830614, 0.5968244482318344, '47%'),
#   Text(-0.5993992784923483, -0.02684222313542927, '8%'),
#   Text(0.07232197598023135, -0.5956253283653364, '44%'),
#   Text(0.5997837159213367, -0.016108821049141863, '1%')])

# %% [markdown]
# Let's check which common fields we have in all of the log types:

# %%
category_set = set()
category_set.add('Message') # every log has a message field

raw_data = [x.replace('=', ' ') for x in df['_raw'].tolist()]

# thanks to Bing Wang from StackOverflow
# link: https://stackoverflow.com/questions/66572861/find-words-that-appear-in-multiple-strings
counter = Counter([w for l in raw_data for w in set(l.split())])

counter
# Out:
# Counter({'Type': 351,
#          'RecordNumber': 351,
#          'Message': 351,
#          'Keywords': 351,
#          'SourceName': 351,
#          'ComputerName': 351,
#          'EventCode': 351,
#          'EventType': 351,
#          'OpCode': 351,
#          'CLIENT-PC': 351,
#          'LogName': 351,
#          'TaskCategory': 351,
#          'Information': 332,
#          '4': 300,
#          'None': 292,
#          '0': 211,
#          'The': 197,
#          'Info': 192,
#          'Classic': 182,
#          'User': 180,
#          'PM': 180,
#          '09/21/2023': 180,
#          'AM': 172,
#          '09/22/2023': 171,
#          'Application': 164,
#          'System': 158,
#          'NOT_TRANSLATED': 155,
#          'SidType': 155,
#          'Sid': 155,
#          'S-1-5-18': 152,
#          'service': 118,
#          'has': 111,
#          'Microsoft-Windows-Security-SPP': 108,
#          'the': 99,
#          'was': 94,
#          'and': 89,
#          'in': 76,
#          'successfully': 73,
#          '1': 71,
#          'Protection': 68,
#          'Software': 68,
#          'Windows': 62,
#          'to': 61,
#          'with': 57,
#          'is': 57,
#          'of': 49,
#          'Microsoft-Windows-Kernel-General': 47,
#          'Id': 47,
#          'License': 46,
#          'modified': 45,
#          '2': 45,
#          'for': 44,
#          '16': 42,
#          'installed': 41,
#          'creating': 40,
#          'keys': 40,
#          'updating': 40,
#          'history': 40,
#          'pages.': 40,
#          'hive': 40,
#          'cleared': 40,
#          'access': 40,
#          'a': 38,
#          'type': 37,
#          'security': 37,
#          'Windows(R)': 36,
#          'Title': 36,
#          '1004': 36,
#          'license.': 36,
#          'Service': 35,
#          'Control': 34,
#          '-': 34,
#          'Name:': 34,
#          '3': 33,
#          'start': 33,
#          'user': 33,
#          '6': 32,
#          'Security': 32,
#          'application': 30,
#          'not': 30,
#          'Success': 30,
#          'UL': 30,
#          '12:04:39': 30,
#          'Microsoft': 30,
#          'new': 29,
#          'using': 29,
#          'Logon': 28,
#          'an': 28,
#          'Type:': 28,
#          'A': 28,
#          'Audit': 28,
#          'administrative': 27,
#          'or': 27,
#          'File': 27,
#          'Subject:': 27,
#          'been': 27,
#          'New': 27,
#          'ID:': 27,
#          'Account': 26,
#          '0x3E7': 26,
#          'Domain:': 26,
#          'auditing.': 26,
#          'registered': 25,
#          'Target': 25,
#          'completed': 24,
#          'Microsoft-Windows-FilterManager': 24,
#          'Filter': 24,
#          'account': 24,
#          'that': 24,
#          'configured': 24,
#          'disabled.': 24,
#          'Information:': 24,
#          'assigned': 24,
#          'process': 24,
#          'Creation': 24,
#          'token': 24,
#          'Process': 24,
#          'S-1-0-0': 24,
#          'Token': 24,
#          'Event': 23,
#          'Elevation': 23,
#          'used': 23,
#          'full': 23,
#          'if': 23,
#          'Reason:': 22,
#          '(10.0,': 22,
#          'loaded': 22,
#          'Manager.': 22,
#          'Label:': 22,
#          'enabled': 22,
#          'program': 22,
#          'groups': 22,
#          'Run': 22,
#          'Administrator': 22,
#          'An': 22,
#          'chooses': 22,
#          'maximum': 22,
#          'indicates': 22,
#          'also': 22,
#          '4688': 22,
#          'Administrators': 22,
#          'disabled': 22,
#          'account.': 22,
#          'Mandatory': 22,
#          'privilege,': 22,
#          'always': 22,
#          'group.': 22,
#          'enabled,': 22,
#          'choose': 22,
#          'Command': 22,
#          'only': 22,
#          'accordance': 22,
#          'require': 22,
#          'as': 22,
#          'limited': 22,
#          'no': 22,
#          'elevated': 22,
#          'removed': 22,
#          'Creator': 22,
#          '0x0': 22,
#          '%%1936': 22,
#          'privileges': 22,
#          'privilege': 22,
#          'administrator.': 22,
#          'created.': 22,
#          'built-in': 22,
#          'Line:': 22,
#          'S-1-16-16384': 22,
#          'policy.': 22,
#          'member': 22,
#          'when': 22,
#          'does': 22,
#          'at': 21,
#          'status': 20,
#          'started': 20,
#          'successfully.': 19,
#          'Error': 18,
#          '(Private)': 18,
#          '(Public)': 18,
#          '16384': 17,
#          'scheduled': 17,
#          're-start': 17,
#          'Successfully': 17,
#          'RulesEngine.': 17,
#          'S-1-5-21-1948427861-2696874323-1688284928-1000': 17,
#          'following': 17,
#          'downlevel': 17,
#          'migration': 17,
#          'Offline': 17,
#          '16394': 17,
#          'succeeded.': 17,
#          'database': 16,
#          'C:\\Windows\\System32\\smss.exe': 16,
#          '11:14:37': 16,
#          'operation': 15,
#          'engine': 15,
#          'ESENT': 15,
#          'from': 14,
#          'General': 14,
#          '12:03:17': 14,
#          'Manager': 13,
#          'be': 13,
#          '100': 13,
#          '12:03:15': 13,
#          'Microsoft-Windows-Service': 12,
#          'policy': 12,
#          'Policy': 12,
#          'oob': 12,
#          'State': 12,
#          'S-1-5-19': 12,
#          'Microsoft-Windows-Kernel-Boot': 12,
#          'Update': 11,
#          'client': 11,
#          '11:14:31': 11,
#          'Defender': 10,
#          'SecurityCenter': 10,
#          'hr': 10,
#          '0x00000000': 10,
#          '1003': 10,
#          '10': 10,
#          '11': 10,
#          'Duplicate': 10,
#          'Priority': 10,
#          'found.': 10,
#          'name': 10,
#          '1034': 10,
#          'definition': 10,
#          'Microsoft-Windows-Winlogon': 9,
#          'notification': 9,
#          'Agent': 9,
#          'Microsoft-Windows-WindowsUpdateClient': 9,
#          'demand': 9,
#          'auto': 9,
#          'changed': 9,
#          'SearchIndexer': 9,
#          'Windows:': 9,
#          'stopped.': 9,
#          'AAD-BlockAADWorkplaceJoin-Default': 9,
#          '12:03:10': 9,
#          '12:02:56': 9,
#          '11:14:20': 9,
#          'SECURITY_PRODUCT_STATE_ON.': 8,
#          'Updated': 8,
#          '15': 8,
#          '0xC004C008': 8,
#          '42:': 8,
#          '4:': 8,
#          'e558417a-5123-4f6f-91e7-385c1c7ca9d4,': 8,
#          'a48938aa-62fa-4966-9d44-9f04da3f72f2,': 8,
#          '24:': 8,
#          '[0xC004F014,': 8,
#          '33:': 8,
#          '11:': 8,
#          'bd3762d7-270d-4760-8fb3-d829ca45278a,': 8,
#          '29:': 8,
#          'msft:rm/algorithm/flags/1.0)(': 8,
#          '0724cb7d-3437-4cb7-93cb-830375d0079d,': 8,
#          '31:': 8,
#          '21:': 8,
#          '[(?)(?)(?)(?)(?)(?)(?)(?)])(1': 8,
#          '37:': 8,
#          '3502365a-f88a-4ba4-822a-5769d3073b65,': 8,
#          'fa755fe6-6739-40b9-8d84-6d0ea3b6d1ab,': 8,
#          '18:': 8,
#          '3f1afc82-f8ac-4f6c-8005-1d233e606eee,': 8,
#          '25:': 8,
#          '19:': 8,
#          '2c293c26-a45a-4a2a-a350-c69a67097529,': 8,
#          '30a42c86-b7a0-4a34-8c90-ff177cb2acb7,': 8,
#          '23:': 8,
#          'b0773a15-df3a-4312-9ad2-83d69648e356,': 8,
#          '2:': 8,
#          ')]': 8,
#          'e0c42288-980c-4788-a014-c080d2e1926e,': 8,
#          '3df374ef-d444-4494-a5a1-4b0d9fd0e203,': 8,
#          'e7a950a2-e548-4f10-bf16-02ec848e0643,': 8,
#          '47:': 8,
#          '0xC004F034)(': 8,
#          '3:': 8,
#          'Licensing': 8,
#          '0xC004F034)(?)(?)(?)(?)(?)(?)])(3': 8,
#          '[(': 8,
#          '20:': 8,
#          '41:': 8,
#          '[0xC004E003,': 8,
#          '2ffd8952-423e-4903-b993-72a1aa44cf82,': 8,
#          '17:': 8,
#          '62f0c100-9c53-4e02-b886-a3528ddfe7f6,': 8,
#          '90da7373-1c51-430b-bf26-c97e9c5cdc31,': 8,
#          '73111121-5638-40f6-bc11-f1d7b0d64300,': 8,
#          '43:': 8,
#          '40:': 8,
#          '12:': 8,
#          '34:': 8,
#          '4de7cb65-cdf1-4de9-8ae8-e3cce27b9f2c,': 8,
#          'd6eadb3b-5ca8-4a6b-986e-35b550756111,': 8,
#          '0xC004F034)])]': 8,
#          '35:': 8,
#          '0)(': 8,
#          '377333b1-8b5d-48d6-9679-1225c872d37c,': 8,
#          '1:': 8,
#          '2936d1d2-913a-4542-b54e-ce5a602a2a38,': 8,
#          '13:': 8,
#          '7cb546c0-c7d5-44d8-9a5c-69ecdd782b69,': 8,
#          '10:': 8,
#          '[0x00000000,': 8,
#          '5:': 8,
#          '1a9a717a-cf13-4ba5-83c3-0fe25fa868d5,': 8,
#          '[(0': 8,
#          '9:': 8,
#          '14:': 8,
#          '8:': 8,
#          '613d217f-7f13-4268-9907-1662339531cd,': 8,
#          '345a5db0-d94f-4e3b-a0c0-7c42f7bc3ebf,': 8,
#          '38:': 8,
#          '50:': 8,
#          '30:': 8,
#          'fe74f55b-0338-41d6-b267-4a201abe7285,': 8,
#          '27:': 8,
#          'd552befb-48cc-4327-8f39-47d2d94f987c,': 8,
#          '22:': 8,
#          '7:': 8,
#          '48:': 8,
#          '44:': 8,
#          '95dca82f-385d-4d39-b85b-5c73fa285d6f,': 8,
#          '39:': 8,
#          ')(3': 8,
#          'eb6d346f-1c60-4643-b960-40ec31596c45,': 8,
#          '0ad2ac98-7bb9-4201-8d92-312299201369,': 8,
#          '0x00000000)(': 8,
#          '55c92734-d682-4d71-983e-d6ec3f16059f': 8,
#          'e4db50ea-bda1-4566-b047-0ca50abc6f07,': 8,
#          '0],': 8,
#          'ef51e000-2659-4f25-8345-3de70a9cf4c4,': 8,
#          '291ece0e-9c38-40ca-a9e1-32cc7ec19507,': 8,
#          '7a802526-4c94-4bd1-ba14-835a1aca2120,': 8,
#          '221a02da-e2a1-4b75-864c-0a4410a33fdf,': 8,
#          'check.': 8,
#          '2de67392-b7a7-462a-b1ca-108dd189f588,': 8,
#          '46:': 8,
#          '4f3da0d2-271d-4508-ae81-626b60809a38,': 8,
#          'c86d5194-4840-4dae-9c1c-0301003a5ab0,': 8,
#          '040fa323-92b1-4baf-97a2-5b67feaefddb,': 8,
#          '32:': 8,
#          'licensing': 8,
#          'ec868e65-fadf-4759-b23e-93fe37f2cc29,': 8,
#          '60b3ec1b-9545-4921-821f-311b129dd6f6,': 8,
#          '51:': 8,
#          '6365275e-368d-46ca-a0ef-fc0404119333,': 8,
#          '82bbc092-bc50-4e16-8e18-b74fc486aec3,': 8,
#          '1,': 8,
#          ')(2': 8,
#          '16:': 8,
#          '721f9237-9341-4453-a661-09e8baa6cca5,': 8,
#          '15:': 8,
#          'f7af7d09-40e4-419c-a49b-eae366689ebd,': 8,
#          '8b351c9c-f398-4515-9900-09df49427262,': 8,
#          'df96023b-dcd9-4be2-afa0-c6c871159ebe,': 8,
#          '49cd895b-53b2-4dc4-a5f7-b18aa019ad37,': 8,
#          '45:': 8,
#          '0,': 8,
#          '8ab9bdd1-1f67-4997-82d9-8878520837d9,': 8,
#          '0xC004F009': 8,
#          '6:': 8,
#          'b68e61d2-68ca-4757-be45-0cc2f3e68eee,': 8,
#          'Status': 8,
#          '49:': 8,
#          '28:': 8,
#          '36:': 8,
#          ')(1': 8,
#          '0)(?)(?)(?)(': 8,
#          'b4bfe195-541e-4e64-ad23-6177f19e395e,': 8,
#          '26:': 8,
#          'started.': 8,
#          'This': 8,
#          'Microsoft-Windows-Dhcp-Client': 8,
#          'DHCPv4': 8,
#          'EventLog': 8,
#          'system': 8,
#          'information': 8,
#          '0x158': 8,
#          'boot': 8,
#          '12:03:07': 8,
#          '11:14:36': 8,
#          'error': 7,
#          'Started': 7,
#          'start.': 7,
#          '7040': 7,
#          '#': 7,
#          '+M(C:0K,': 7,
#          '[1]': 7,
#          'WT': 7,
#          'Microsoft-Windows-Kernel-Power': 7,
#          'state': 7,
#          '11:33:08': 7,
#          'event.': 6,
#          'unavailable': 6,
#          'handle': 6,
#          'winlogon': 6,
#          'subscriber': 6,
#          '[8]': 6,
#          '[6]': 6,
#          '[7]': 6,
#          '(Time': 6,
#          'seconds)': 6,
#          'Sequence:': 6,
#          '+J(0)': 6,
#          '[2]': 6,
#          '0K,': 6,
#          '[9]': 6,
#          'PgRf:0,': 6,
#          'Data:': 6,
#          '[3]': 6,
#          'Additional': 6,
#          '[11]': 6,
#          'Timing': 6,
#          'Rd:0/0,': 6,
#          '+J(CM:0,': 6,
#          '[4]': 6,
#          '[5]': 6,
#          'Dy:0/0,': 6,
#          'Internal': 6,
#          '[10]': 6,
#          '(2)': 6,
#          '(0).': 6,
#          'instance': 6,
#          'Launch': 6,
#          'can': 6,
#          '12:04:42': 6,
#          '12:04:41': 6,
#          'store': 6,
#          'phone': 6,
#          'Publishing': 6,
#          'shutdown': 6,
#          "'CldFlt'": 6,
#          'Microsoft-Windows-Directory-Services-SAM': 6,
#          'more': 6,
#          'see': 6,
#          'For': 6,
#          'time': 6,
#          'C:\\Windows\\System32\\wininit.exe': 6,
#          '0x1fc': 6,
#          '0x1f4': 6,
#          '0x1a4': 6,
#          'power': 6,
#          '0x4': 6,
#          'Fault': 6,
#          'Report': 6,
#          'Id:': 6,
#          '{12D3E340-232D-489E-87F3-8988660A1B68}:': 6,
#          'Video.UI': 6,
#          '11:17:07': 6,
#          '11:14:35': 6,
#          'code:': 5,
#          'Activation': 5,
#          '<SessionEnv>': 5,
#          'Download,': 5,
#          'Download': 5,
#          'downloading': 5,
#          'update.': 5,
#          '44': 5,
#          '[14]': 5,
#          '[15]': 5,
#          '[12]': 5,
#          'CM': 5,
#          '[13]': 5,
#          'Microsoft-Windows-DistributedCOM': 5,
#          'Component': 5,
#          'settings': 5,
#          'tool.': 5,
#          'LocalHost': 5,
#          'SID': 5,
#          'LRPC)': 5,
#          'COM': 5,
#          'running': 5,
#          'container': 5,
#          'Warning': 5,
#          'Local': 5,
#          'CLSID': 5,
#          'Server': 5,
#          'grant': 5,
#          '10016': 5,
#          'do': 5,
#          'Services': 5,
#          'permission': 5,
#          'APPID': 5,
#          '(Using': 5,
#          'address': 5,
#          'Instrumentation': 5,
#          'Microsoft-Windows-WMI': 5,
#          'Management': 5,
#          'DHCPv6': 5,
#          'ServiceShutdown': 5,
#          'Current': 5,
#          'system.': 5,
#          'on': 5,
#          'P7:': 5,
#          'P1:': 5,
#          'P2:': 5,
#          'Hashed': 5,
#          'Attached': 5,
#          'available': 5,
#          'may': 5,
#          'here:': 5,
#          'P3:': 5,
#          'Cab': 5,
#          'Not': 5,
#          'P10:': 5,
#          'signature:': 5,
#          'P4:': 5,
#          'P9:': 5,
#          'Problem': 5,
#          'bucket:': 5,
#          'P5:': 5,
#          '1001': 5,
#          'files': 5,
#          'Reporting': 5,
#          'solution:': 5,
#          'These': 5,
#          'P8:': 5,
#          'bucket': 5,
#          'P6:': 5,
#          'Rechecking': 5,
#          'files:': 5,
#          'Status:': 5,
#          'Response:': 5,
#          'Guid:': 5,
#          'Analysis': 5,
#          'symbol:': 5,
#          '31e71c49-8da7-4a2f-ad92-45d98a1c79ba;Action': 4,
#          'Command-line': 4,
#          'arguments:': 4,
#          '(slui.exe)': 4,
#          '55c92734-d682-4d71-983e-d6ec3f16059f;SkuId': 4,
#          '8198': 4,
#          'AutoActivate;AppId': 4,
#          'failed': 4,
#          'e558417a-5123-4f6f-91e7-385c1c7ca9d4;NotificationInterval': 4,
#          'RuleId': 4,
#          '1440;Trigger': 4,
#          '6000': 4,
#          'Intelligent': 4,
#          'Transfer': 4,
#          'Background': 4,
#          'Lg:0/0)': 4,
#          '(1)': 4,
#          '12:05:32': 4,
#          'PF:0K': 4,
#          'PF:12K': 4,
#          'P:12K)': 4,
#          'NT': 4,
#          'Unavailable': 4,
#          'application-specific': 4,
#          'AUTHORITY\\SYSTEM': 4,
#          '(Unavailable).': 4,
#          '(S-1-5-18)': 4,
#          'update:': 4,
#          'Installation': 4,
#          'Installation,': 4,
#          'Kernel': 4,
#          '12:04:40': 4,
#          'volume': 4,
#          '5': 4,
#          'initialized': 4,
#          'ServiceStart': 4,
#          'Microsoft-Windows-DHCPv6-Client': 4,
#          '(Version': 4,
#          'log': 4,
#          'password': 4,
#          'please': 4,
#          'default': 4,
#          'are': 4,
#          'being': 4,
#          'Time': 4,
#          'C:\\Windows\\System32\\csrss.exe': 4,
#          'count': 4,
#          'throttle': 4,
#          'management': 4,
#          'Microsoft-Windows-Kernel-Processor-Power': 4,
#          'States': 4,
#          'performance': 4,
#          'group': 4,
#          'percentage:': 4,
#          '2808': 4,
#          '47': 4,
#          'exposes': 4,
#          '(1': 4,
#          'Processor': 4,
#          'Frequency': 4,
#          'type:': 4,
#          'ACPI': 4,
#          '(MHz):': 4,
#          'Idle': 4,
#          '(C)': 4,
#          'Nominal': 4,
#          'Maximum': 4,
#          'state(s))': 4,
#          'capabilities:': 4,
#          'Minimum': 4,
#          '55': 4,
#          'Performance': 4,
#          'No': 4,
#          'Registry': 4,
#          '0x5c': 4,
#          '12:03:08': 4,
#          '20': 4,
#          '32': 4,
#          'due': 4,
#          '12:09:20': 3,
#          'failed.': 3,
#          'End': 3,
#          'Sku': 3,
#          'Acquisition': 3,
#          '1014': 3,
#          'e558417a-5123-4f6f-91e7-385c1c7ca9d4': 3,
#          'acquisition': 3,
#          'failure': 3,
#          '8200': 3,
#          'details.': 3,
#          'Customer': 3,
#          'Program': 3,
#          'Notification': 3,
#          'Improvement': 3,
#          'Experience': 3,
#          '1101': 3,
#          '12:07:52': 3,
#          'gupdate': 3,
#          'necessary': 3,
#          'dbv': 3,
#          'WS:4K': 3,
#          'Fs:1,': 3,
#          'WS:12K': 3,
#          '(5)': 3,
#          'Fs:24,': 3,
#          'P:0K)': 3,
#          'WS:32K': 3,
#          'Fs:10,': 3,
#          'Lg:3480/2)': 3,
#          'WS:40K': 3,
#          '+J(CM:1,': 3,
#          '+J(CM:2,': 3,
#          '(1,': 3,
#          'PgRf:2,': 3,
#          'Rd:0/1,': 3,
#          'Fs:2,': 3,
#          '105': 3,
#          '[16]': 3,
#          'starting': 3,
#          '(10.00.19045.0000)': 3,
#          '102': 3,
#          '12:05:31': 3,
#          'starting.': 3,
#          '900': 3,
#          'edgeupdate': 3,
#          'Modules': 3,
#          'Installer': 3,
#          'Setup': 3,
#          '27': 3,
#          'Microsoft-Windows-Servicing': 3,
#          '12:04:37': 3,
#          '\u200e2089\u200e-\u200e06\u200e-\u200e12T20:24:15.000000000Z)': 3,
#          'Microsoft-Windows-User': 3,
#          'Profile': 3,
#          'logging': 3,
#          'manager': 3,
#          'events': 3,
#          '521': 3,
#          'Active': 3,
#          'change.': 3,
#          '220': 3,
#          'battery': 3,
#          'Events': 3,
#          '12:03:09': 3,
#          'waiting': 3,
#          '33': 3,
#          '25': 3,
#          'operating': 3,
#          'down': 3,
#          'shutting': 3,
#          '12:00:46': 3,
#          '"C:\\Program': 3,
#          'LocalSystem': 3,
#          'Start': 3,
#          'Account:': 3,
#          '7045': 3,
#          'Google': 3,
#          'mode': 3,
#          '268435456': 3,
#          'package': 3,
#          'version:': 3,
#          '4b9412b0-b4ca-4d4a-a8f2-e3234bb9231f': 3,
#          'binary:': 3,
#          'missing': 3,
#          '楆敬›瑳牯汥祡畯\u2e74灣⡰㘱㠹': 3,
#          '10.0.19041.3385:1': 3,
#          'Matching': 3,
#          'amd64_dual_wvmbusr.inf_31bf3856ad364e35_10.0.19041.3393_none_67b042bbb5347f14': 3,
#          '\u202d潃灭湯湥却潴敲㨺剃睡瑓牯䱥祡畯㩴䠺摹慲整楆敬': 3,
#          'WindowsServicingFailureInfo': 3,
#          'component:': 3,
#          'wvmbusr.inf': 3,
#          '0x800F0984': 3,
#          'parameter': 3,
#          'JET_efvAllowHigherPersistedFormat).': 3,
#          '|': 3,
#          '0x410022D8': 3,
#          '(8920': 3,
#          'version': 3,
#          'format': 3,
#          '(10628,D,35)': 3,
#          '(4)': 3,
#          '11:19:21': 3,
#          '11:17:20': 3,
#          'Logging/Recovery': 3,
#          '11:16:41': 3,
#          '11:16:38': 3,
#          '11:14:42': 3,
#          '\u200e2063\u200e-\u200e04\u200e-\u200e13T08:46:34.000000000Z)': 3,
#          '11:14:25': 3,
#          'UserLogon;SessionId': 2,
#          '12:09:19': 2,
#          '7001': 2,
#          '12:09:06': 2,
#          'critical': 2,
#          '6003': 2,
#          'NOTE:': 2,
#          'message': 2,
#          'MC': 2,
#          'defines': 2,
#          'force': 2,
#          '12:05:34': 2,
#          'Microsoft-Windows-Search': 2,
#          'FACILITY_WINDOWS': 2,
#          'inside': 2,
#          'Search': 2,
#          'output': 2,
#          'empty.': 2,
#          'above': 2,
#          'leaving': 2,
#          'it': 2,
#          'guard': 2,
#          'dummy': 2,
#          'instead': 2,
#          'Lg:0/0).': 2,
#          'attached': 2,
#          '326': 2,
#          'Saved': 2,
#          '0.000019': 2,
#          'PgRf:1,': 2,
#          'PgRf:40,': 2,
#          '+J(CM:5,': 2,
#          '0.0': 2,
#          'Rd:14/2,': 2,
#          'Cache:': 2,
#          'PgRf:42,': 2,
#          'PgRf:23,': 2,
#          'PF:32K': 2,
#          'C:\\ProgramData\\Microsoft\\Search\\Data\\Applications\\Windows\\Windows.edb).': 2,
#          'Lg:54/1)': 2,
#          '96K,': 2,
#          'Fs:3,': 2,
#          'P:32K)': 2,
#          'Rd:0/5,': 2,
#          'lgposAttach': 2,
#          '1568.110.240': 2,
#          'P:0K).': 2,
#          '356K,': 2,
#          'PF:-1020K': 2,
#          'P:64K)': 2,
#          'P:-1020K)': 2,
#          'PF:356K': 2,
#          'WS:44K': 2,
#          '100K,': 2,
#          'P:356K)': 2,
#          '32K,': 2,
#          '104K,': 2,
#          'WS:100K': 2,
#          '40K,': 2,
#          'P:24K)': 2,
#          '68K,': 2,
#          'WS:0K': 2,
#          'PF:68K': 2,
#          'PF:1028K': 2,
#          'Fs:11,': 2,
#          'Lg:616/1)': 2,
#          'WS:104K': 2,
#          '1028K,': 2,
#          '4K,': 2,
#          '44K,': 2,
#          'PF:24K': 2,
#          'P:1028K)': 2,
#          'P:68K)': 2,
#          '-0.000001': 2,
#          'PF:64K': 2,
#          '12K,': 2,
#          'Fs:26,': 2,
#          'Center': 2,
#          'Windows.SecurityCenter.WscDataProtection': 2,
#          '12:05:24': 2,
#          '903': 2,
#          '2023-09': 2,
#          'Version': 2,
#          'Systems': 2,
#          '22H2': 2,
#          'Successful:': 2,
#          '(KB5030211)': 2,
#          'Cumulative': 2,
#          '19': 2,
#          'x64-based': 2,
#          'KB5030211': 2,
#          'state.': 2,
#          'Installed': 2,
#          '902': 2,
#          'oem': 2,
#          '12:04:38': 2,
#          '0x00000000,': 2,
#          'msft:spp/volume/services/kms/activationinfo/1.0,': 2,
#          'msft:spp/ActionScheduler/1.0,': 2,
#          'msft:rm/algorithm/inherited/1.0,': 2,
#          'msft:rm/algorithm/pkey/detect,': 2,
#          'msft:spp/windowsfunctionality/agent/7.0,': 2,
#          'msft:spp/statecollector/pkey,': 2,
#          '1066': 2,
#          'Initialization': 2,
#          'msft:spp/TaskScheduler/1.0,': 2,
#          'msft:spp/volume/services/kms/1.0,': 2,
#          'C:\\Windows\\system32\\sppobjs.dll,': 2,
#          'C:\\Windows\\system32\\sppwinob.dll,': 2,
#          'msft:rm/algorithm/phone/1.0,': 2,
#          'objects.': 2,
#          'Parameters:TriggerStarted:6': 2,
#          '12:04:21': 2,
#          'subsystems': 2,
#          '5617': 2,
#          'load:': 2,
#          'driver(s)': 2,
#          'boot-start': 2,
#          'did': 2,
#          '7026': 2,
#          'dam': 2,
#          'system-start': 2,
#          '5615': 2,
#          'sucessfully': 2,
#          '51046': 2,
#          '50103': 2,
#          '50036': 2,
#          '\u200e2005\u200e-\u200e08\u200e-\u200e08T23:17:00.000000000Z)': 2,
#          "'bindflt'": 2,
#          "'storqosflt'": 2,
#          '\u200e2007\u200e-\u200e04\u200e-\u200e09T21:08:30.000000000Z)': 2,
#          'unloaded': 2,
#          '10.0,': 2,
#          "'wcifs'": 2,
#          '\u200e1986\u200e-\u200e08\u200e-\u200e13T23:58:59.000000000Z)': 2,
#          "'luafv'": 2,
#          '9': 2,
#          '6013': 2,
#          'uptime': 2,
#          'seconds.': 2,
#          '6005': 2,
#          'Free.': 2,
#          '10.00.': 2,
#          '6009': 2,
#          'Multiprocessor': 2,
#          '19045': 2,
#          '(R)': 2,
#          '1531': 2,
#          '16983': 2,
#          'clients': 2,
#          'methods.': 2,
#          'legacy': 2,
#          'set': 2,
#          '2150956.': 2,
#          'RPC': 2,
#          'https://go.microsoft.com/fwlink/?linkid': 2,
#          'periodic': 2,
#          'summary': 2,
#          'now': 2,
#          'call': 2,
#          'change': 2,
#          'remote': 2,
#          'https://go.microsoft.com/fwlink/?LinkId': 2,
#          '2097191.': 2,
#          'domain': 2,
#          'length-related': 2,
#          'MinimumPasswordLength:': 2,
#          '16977': 2,
#          '-1': 2,
#          'minimum': 2,
#          'settings.': 2,
#          'MinimumPasswordLengthAudit:': 2,
#          'RelaxMinimumPasswordLengthLimits:': 2,
#          'descriptor:': 2,
#          'Remote': 2,
#          '787651.': 2,
#          'calls': 2,
#          'O:SYG:SYD:(A;;RC;;;BA).': 2,
#          'SAM': 2,
#          '16962': 2,
#          'restricted': 2,
#          'http://go.microsoft.com/fwlink/?LinkId': 2,
#          'Credential': 2,
#          '0x0,': 2,
#          'Guard': 2,
#          '14': 2,
#          'configuration:': 2,
#          'Microsoft-Windows-Wininit': 2,
#          'refreshed': 2,
#          'bias': 2,
#          'exit': 2,
#          '24': 2,
#          '-180.': 2,
#          'reason': 2,
#          '0.': 2,
#          'zone': 2,
#          'C:\\Windows\\System32\\lsass.exe': 2,
#          'C:\\Windows\\System32\\services.exe': 2,
#          'C:\\Windows\\System32\\winlogon.exe': 2,
#          '0x1b0': 2,
#          '0x170': 2,
#          'C:\\Windows\\System32\\autochk.exe': 2,
#          '203': 2,
#          '172': 2,
#          'Disconnected,': 2,
#          'standby:': 2,
#          'compliance': 2,
#          'Connectivity': 2,
#          'NIC': 2,
#          'Disable': 2,
#          'Signature': 2,
#          'Settings:': 2,
#          'Configuration': 2,
#          'Test': 2,
#          'Load': 2,
#          'Integrity': 2,
#          'Change': 2,
#          'Policy:': 2,
#          'Off': 2,
#          'Boot': 2,
#          'Other': 2,
#          'Options:': 2,
#          'Flight': 2,
#          'Data': 2,
#          'Advanced': 2,
#          'Checks:': 2,
#          'VSM': 2,
#          'Logging:': 2,
#          '4826': 2,
#          'loaded.': 2,
#          'HyperVisor': 2,
#          'Signing:': 2,
#          'Debugging:': 2,
#          'Default': 2,
#          'Access': 2,
#          'Process:': 2,
#          'primary': 2,
#          'process.': 2,
#          '4696': 2,
#          "'npsvctrig'": 2,
#          '\u200e2025\u200e-\u200e01\u200e-\u200e06T05:41:12.000000000Z)': 2,
#          "'FileCrypt'": 2,
#          '\u200e2002\u200e-\u200e03\u200e-\u200e01T14:12:42.000000000Z)': 2,
#          'Microsoft-Windows-Ntfs': 2,
#          '98': 2,
#          'needed.': 2,
#          'action': 2,
#          'healthy.': 2,
#          '(\\Device\\HarddiskVolume1)': 2,
#          'Volume': 2,
#          'C:': 2,
#          "'WdFilter'": 2,
#          '\u200e2035\u200e-\u200e08\u200e-\u200e05T03:44:58.000000000Z)': 2,
#          '\u200e2023\u200e-\u200e04\u200e-\u200e23T05:17:53.000000000Z)': 2,
#          "'Wof'": 2,
#          "'FileInfo'": 2,
#          '\u200e2062\u200e-\u200e12\u200e-\u200e23T08:21:06.000000000Z)': 2,
#          'initialized.': 2,
#          'fault': 2,
#          'iommu': 2,
#          'Microsoft-Windows-HAL': 2,
#          'reporting': 2,
#          'data': 2,
#          'true': 2,
#          'enabled:': 2,
#          'updated.': 2,
#          'count:': 2,
#          'during': 2,
#          'seconds': 2,
#          'registry': 2,
#          'Leap': 2,
#          'configuration': 2,
#          'leap': 2,
#          'Old': 2,
#          'second': 2,
#          'spent': 2,
#          'bootmgr': 2,
#          'input.': 2,
#          '58': 2,
#          'ms': 2,
#          '0x1': 2,
#          ...})

# %% [markdown]
# As we can see, we have many field, but not all of them appear in all of the logs.
# So let's try to extract the fields that do appear in all of the logs:

# %%
common_fields = [x[0] for x in counter.most_common() if x[1] == len(raw_data)]
print('The list of fields that appear in all the logs are:\n', [x[0] for x in counter.most_common() if x[1] == len(raw_data)])
print('And the number of fields is: ', len(common_fields))
# Out:
# The list of fields that appear in all the logs are:
#  ['Type', 'RecordNumber', 'Message', 'Keywords', 'SourceName', 'ComputerName', 'EventCode', 'EventType', 'OpCode', 'CLIENT-PC', 'LogName', 'TaskCategory']
# And the number of fields is:  12

# %% [markdown]
# <u>Note:</u>
# 1. 'CLIENT-PC' is not a real field, so we can safely ignore it.<br>
# 2. We can also add the Date and Time as features.<br>

# %% [markdown]
# So, in conclusion, we have 13 different fields that appear in all the log types.<br>
# Now let's build the dataset with those fields as features.

# %%
LogName = []
Date = []
Time = []
ComputerName = []
SourceName = []
TaskCategory = []
EventType = []
Message = []
Keywords = []
OpCode = []
EventCode = []
Type = []
RecordNumber = []

for i in range(0,len(df)):
    current_log = df.iloc[i]['_raw']
    Date.append(current_log[0:10])
    Time.append(current_log[11:22])
    LogName.append(re.search('LogName=(.*)\n', current_log).group(1))
    ComputerName.append(re.search('ComputerName=(.*)\n', current_log).group(1))
    SourceName.append(re.search('SourceName=(.*)\n', current_log).group(1))
    TaskCategory.append(re.search('TaskCategory=(.*)\n', current_log).group(1))
    EventType.append(re.search('EventType=(.*)\n', current_log).group(1))
    Keywords.append(re.search('Keywords=(.*)\n', current_log).group(1))
    OpCode.append(re.search('OpCode=(.*)\n', current_log).group(1))
    EventCode.append(re.search('EventCode=(.*)\n', current_log).group(1))
    Type.append(re.search('Type=(.*)\n', current_log).group(1))
    RecordNumber.append(re.search('RecordNumber=(.*)\n', current_log).group(1))
    Message.append(re.search('Message=(.*)', current_log).group(1))

df_cleaned = pd.DataFrame({ 'LogName' : LogName,
                         'Date' : Date,
                         'Time' : Time,
                         'ComputerName' : ComputerName,
                         'SourceName' : SourceName,
                         'TaskCategory' : TaskCategory,
                         'EventType' : EventType,
                         'Keywords' : Keywords,
                         'OpCode' : OpCode,
                         'EventCode' : EventCode,
                         'Type' : Type,
                         'RecordNumber' : RecordNumber,
                         'Message' : Message })

df_cleaned.head(5)
# Out:
#        LogName        Date         Time ComputerName  \
# 0  Application  09/22/2023  12:10:15 AM    CLIENT-PC
# 1       System  09/22/2023  12:10:01 AM    CLIENT-PC
# 2  Application  09/22/2023  12:09:45 AM    CLIENT-PC
# 3       System  09/22/2023  12:09:23 AM    CLIENT-PC
# 4  Application  09/22/2023  12:09:20 AM    CLIENT-PC
#
#                          SourceName TaskCategory EventType Keywords OpCode  \
# 0    Microsoft-Windows-Security-SPP         None         4  Classic   None
# 1  Microsoft-Windows-Kernel-General         None         4     None   Info
# 2                    SecurityCenter         None         4  Classic   Info
# 3  Microsoft-Windows-Kernel-General         None         4     None   Info
# 4    Microsoft-Windows-Security-SPP         None         2  Classic   None
#
#   EventCode Type RecordNumber  \
# 0     16384    4         3267
# 1        16    4         2279
# 2        15    4         3266
# 3        16    4         2278
# 4      8198    2         3265
#
#                                              Message
# 0  Successfully scheduled Software Protection ser...
# 1  The access history in hive \??\C:\Users\Commun...
# 2  Updated Windows Defender status successfully t...
# 3  The access history in hive \??\C:\Users\Commun...
# 4  License Activation (slui.exe) failed with the ...

# %% [markdown]
# Let's fix some of the features types:

# %%
df_cleaned['EventType'] = df_cleaned['EventType'].astype(int)
df_cleaned['EventCode'] = df_cleaned['EventCode'].astype(int)
df_cleaned['Type'] = df_cleaned['Type'].astype(int)
df_cleaned['RecordNumber'] = df_cleaned['RecordNumber'].astype(int)
df_cleaned['Date'] = pd.to_datetime(df_cleaned['Date'], format='%m/%d/%Y')
df_cleaned['Time'] = pd.to_datetime(df_cleaned['Time'], format='%I:%M:%S %p').dt.time

df_cleaned.dtypes
# Out:
# LogName                 object
# Date            datetime64[ns]
# Time                    object
# ComputerName            object
# SourceName              object
# TaskCategory            object
# EventType                int32
# Keywords                object
# OpCode                  object
# EventCode                int32
# Type                     int32
# RecordNumber             int32
# Message                 object
# dtype: object

# %% [markdown]
# Now let's save the new dataset as <b>'good_samples_cleaned.csv'</b>:

# %%
df_cleaned.to_csv('good_samples_cleaned.csv', index=False)

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
import pickle

# %%
# df_good = pd.read_csv('good_samples_cleaned.csv')
# df_bad = pd.read_csv('bad_samples_cleaned.csv')
# df = pd.concat([df_good, df_bad], ignore_index=True, sort=False)

df = pd.read_csv('good_samples_cleaned.csv')

df.head(5)
# Out:
#        LogName        Date      Time ComputerName  \
# 0  Application  2023-09-22  00:10:15    CLIENT-PC
# 1       System  2023-09-22  00:10:01    CLIENT-PC
# 2  Application  2023-09-22  00:09:45    CLIENT-PC
# 3       System  2023-09-22  00:09:23    CLIENT-PC
# 4  Application  2023-09-22  00:09:20    CLIENT-PC
#
#                          SourceName TaskCategory  EventType Keywords OpCode  \
# 0    Microsoft-Windows-Security-SPP          NaN          4  Classic    NaN
# 1  Microsoft-Windows-Kernel-General          NaN          4      NaN   Info
# 2                    SecurityCenter          NaN          4  Classic   Info
# 3  Microsoft-Windows-Kernel-General          NaN          4      NaN   Info
# 4    Microsoft-Windows-Security-SPP          NaN          2  Classic    NaN
#
#    EventCode  Type  RecordNumber  \
# 0      16384     4          3267
# 1         16     4          2279
# 2         15     4          3266
# 3         16     4          2278
# 4       8198     2          3265
#
#                                              Message
# 0  Successfully scheduled Software Protection ser...
# 1  The access history in hive \??\C:\Users\Commun...
# 2  Updated Windows Defender status successfully t...
# 3  The access history in hive \??\C:\Users\Commun...
# 4  License Activation (slui.exe) failed with the ...

# %%
# Explicitly specify date and time formats
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d', errors='coerce')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce')
df['Hour'] = df['Time'].dt.hour
df['Minute'] = df['Time'].dt.minute
df['Second'] = df['Time'].dt.second

df.drop(['Date','Time'], axis=1, inplace=True)

# %%
# Initialize a LabelEncoder
label_encoder = LabelEncoder()

# Encode a specific column (e.g., 'SourceName')
df['LogName'] = label_encoder.fit_transform(df['LogName'])
df['Keywords'] = label_encoder.fit_transform(df['Keywords'])
df['TaskCategory'] = label_encoder.fit_transform(df['TaskCategory'])
df['SourceName'] = label_encoder.fit_transform(df['SourceName'])
df['OpCode'] = label_encoder.fit_transform(df['OpCode'])
df['ComputerName'] = label_encoder.fit_transform(df['OpCode'])

# %%
# Initialize CountVectorizer
vectorizer = CountVectorizer(max_features=1000, stop_words='english')

# Fit and transform the 'Message' column
message_bow = vectorizer.fit_transform(df['Message'])

# Convert the bag of words representation to a DataFrame
message_df = pd.DataFrame(message_bow.toarray(), columns=vectorizer.get_feature_names_out())

# Add the BoW representation as new columns in your original DataFrame
df = pd.concat([df, message_df], axis=1)

df.drop(['Message'], axis=1, inplace=True)

# %%
df.tail(5)
# Out:
#      LogName  ComputerName  SourceName  TaskCategory  EventType  Keywords  \
# 346        3             1          13            10          4         6
# 347        3             1          13             9          4         6
# 348        3             1          13             8          4         6
# 349        3             1          13            15          4         6
# 350        3             1          14             0          4         6
#
#      OpCode  EventCode  Type  RecordNumber  ...  wsearch  x64  \
# 346       1         27     4          2131  ...        0    0
# 347       1         25     4          2130  ...        0    0
# 348       1         20     4          2129  ...        0    0
# 349       1        153     4          2128  ...        0    0
# 350       1         12     4          2127  ...        0    0
#
#      xboxapp_8wekyb3d8bbwe  xboxgamingoverlay_8wekyb3d8bbwe  \
# 346                      0                                0
# 347                      0                                0
# 348                      0                                0
# 349                      0                                0
# 350                      0                                0
#
#      xboxidentityprovider_8wekyb3d8bbwe  yourphone_8wekyb3d8bbwe  zone  \
# 346                                   0                        0     0
# 347                                   0                        0     0
# 348                                   0                        0     0
# 349                                   0                        0     0
# 350                                   0                        0     0
#
#      zunemusic_11  zunemusic_8wekyb3d8bbwe  zunevideo_8wekyb3d8bbwe
# 346             0                        0                        0
# 347             0                        0                        0
# 348             0                        0                        0
# 349             0                        0                        0
# 350             0                        0                        0
#
# [5 rows x 521 columns]

# %%
X = df

# Create and train the Isolation Forest model
model = IsolationForest(contamination=0.05, random_state=42)  # You can adjust the contamination parameter
model.fit(X)
# Out:
# IsolationForest(contamination=0.05, random_state=42)

# %%
# Predict anomaly scores for each data point
anomaly_scores = model.decision_function(X)

# Add the anomaly scores as a new column in your DataFrame
df['AnomalyScore'] = anomaly_scores

# Identify anomalies based on a threshold (you can adjust this threshold)
threshold = -0.2
anomalies = df[df['AnomalyScore'] < threshold]

# Extract the original columns for the anomalies
#anomalies = anomalies[df]

# %%
df['AnomalyScore'] = anomaly_scores

# %%
df[df['AnomalyScore'] < -0.185]
# Out:
# Empty DataFrame
# Columns: [LogName, ComputerName, SourceName, TaskCategory, EventType, Keywords, OpCode, EventCode, Type, RecordNumber, Year, Month, Day, Hour, Minute, Second, 00, 0000, 000000000z, 01, 01t14, 02, 03, 04, 05t03, 06, 06t05, 07, 07z, 08, 08t23, 09, 09t21, 0_x64__8wekyb3d8bbwe, 0_x64__cw5n1h2txyewy, 0_x86__8wekyb3d8bbwe, 0x0, 0x1, 0x22d8, 0x22ec, 0x23dc, 0x410022d8, 0x64b5a80d, 0xc004c008, 10, 100, 1000, 10070, 10628, 11090, 12, 12017, 12d3e340, 12t20, 1353, 13t08, 13t23, 14, 14326, 15, 1525878191447436250, 15z, 16, 1673, 17, 17002, 17z, 180, 19, 19041, 19044, 19045, 1986, 20, 2002, 2004, 2005, 2007, 2023, 2025, 2035, 2062, 2063, 2089, 21, 2102, 2104549068006373076, 21580, 219, 21t20, 21t21, 22, 2244, 22h2, 22t20, 22t21, 23012, 2308, 232d, 23t05, ...]
# Index: []
#
# [0 rows x 522 columns]

# %%
with open('isolation_forest_model.pkl', 'wb') as fout:
    pickle.dump((vectorizer, model), fout)

# %%
df.shape
# Out:
# (351, 522)
